# %%
exec(open("../../header.py").read())

# %%
RESULTS_DIR()
# Out:
# '/home/ay1626/NLU_data/results/'

# %%
a = pickle.load(open(RESULTS_DIR('20news/bert-base-uncased/train/bert_encoded_segments_list_0.9999.pkl'), "rb"))

# %%
a
# Out:
# {'train_loss': [2.972411652345572,
#   2.8871815529832388,
#   2.8315717211456133,
#   2.7833124194669194,
#   2.7446952414491563,
#   2.72871174756593,
#   2.7059812331309687,
#   2.6922046804104998,
#   2.6809331074826765,
#   2.664074531112382,
#   2.6367115484149823,
#   2.6258909346651587,
#   2.6108354053199494,
#   2.593432160757455,
#   2.5928678118291706,
#   2.5895537895525553,
#   2.5734489071548285,
#   2.571964059002002,
#   2.560737113124739,
#   2.552631114819986,
#   2.543262714324924,
#   2.5210936028515087,
#   2.5261375099833208,
#   2.5127050075176993,
#   2.5016812074749852,
#   2.4968066379877154,
#   2.4850577989683327,
#   2.5215516826978406,
#   2.495126545364843,
#   2.4825861298779217,
#   2.4752654100253446,
#   2.479999088578429,
#   2.4666819987802318,
#   2.4626826960902592,
#   2.4636548726062086,
#   2.4563907914366316,
#   2.451736923707769,
#   2.452131797133454,
#   2.4447507598855975,
#   2.4550092918727904,
#   2.443973830836608,
# ...
